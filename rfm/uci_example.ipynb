# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('Online Retail.xlsx')

# %%
df1 = df

# %%
df1.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# ## Exploring and Cleaning Data

# %%
df1.Country.nunique()
# Out:
# 38

# %%
df.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia', 'Czech Republic',
#        'Canada', 'Unspecified', 'Brazil', 'USA', 'European Community',
#        'Malta', 'RSA'], dtype=object)

# %%
customer_country=df1[['Country', 'CustomerID']].drop_duplicates()

# %%
customer_country.groupby(['Country'])['CustomerID'].aggregate('count').reset_index().sort_values('CustomerID',ascending=False)
# Out:
#                  Country  CustomerID
# 36        United Kingdom        3950
# 14               Germany          95
# 13                France          87
# 31                 Spain          31
# 3                Belgium          25
# 33           Switzerland          21
# 27              Portugal          19
# 19                 Italy          15
# 12               Finland          12
# 1                Austria          11
# 25                Norway          10
# 24           Netherlands           9
# 0              Australia           9
# 6        Channel Islands           9
# 9                Denmark           9
# 7                 Cyprus           8
# 32                Sweden           8
# 20                 Japan           8
# 26                Poland           6
# 34                   USA           4
# 5                 Canada           4
# 37           Unspecified           4
# 18                Israel           4
# 15                Greece           4
# 10                  EIRE           3
# 23                 Malta           2
# 35  United Arab Emirates           2
# 2                Bahrain           2
# 22             Lithuania           1
# 8         Czech Republic           1
# 21               Lebanon           1
# 28                   RSA           1
# 29          Saudi Arabia           1
# 30             Singapore           1
# 17               Iceland           1
# 4                 Brazil           1
# 11    European Community           1
# 16             Hong Kong           0

# %%
df1 = df1.loc[df1['Country'] == 'United Kingdom']

# %%
#check for missing values in each column
df1.isnull().sum(axis=0)
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     133600
# Country             0
# dtype: int64

# %%
#removing missing customer IDs
df1 = df1[pd.notnull(df1['CustomerID'])]

# %%
#check minimum values of unitprice and quanitity
df1.Quantity.min()
# Out:
# -80995

# %%
df.UnitPrice.min()
# Out:
# -11062.059999999999

# %%
df1 = df1[(df1['Quantity']>0)]

# %%
df1.shape
# Out:
# (354345, 8)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 354345 entries, 0 to 541893
# Data columns (total 8 columns):
# InvoiceNo      354345 non-null object
# StockCode      354345 non-null object
# Description    354345 non-null object
# Quantity       354345 non-null int64
# InvoiceDate    354345 non-null datetime64[ns]
# UnitPrice      354345 non-null float64
# CustomerID     354345 non-null float64
# Country        354345 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 24.3+ MB

# %%
def unique_counts(df1):
   for i in df1.columns:
       count = df1[i].nunique()
       print(i, ": ", count)
unique_counts(df1)
# Out:
# InvoiceNo :  16649
# StockCode :  3645
# Description :  3844
# Quantity :  294
# InvoiceDate :  15615
# UnitPrice :  403
# CustomerID :  3921
# Country :  1

# %%
df1['TotalPrice'] = df1['Quantity'] * df1['UnitPrice']

# %% [markdown]
# ## RFM Customer Segmentation

# %%
df1['InvoiceDate'].max()
# Out:
# Timestamp('2011-12-09 12:49:00')

# %%
import datetime as dt
NOW = dt.datetime(2011,12,10)

# %%
df1['InvoiceDate'] = pd.to_datetime(df1['InvoiceDate'])

# %%
#Creating an RFM Table
rfmTable = df1.groupby('CustomerID').agg(
    {
        'InvoiceDate': lambda x: (NOW - x.max()).days, 
        'InvoiceNo': lambda x: len(x), 'TotalPrice': lambda x: x.sum()
     }
)
rfmTable['InvoiceDate'] = rfmTable['InvoiceDate'].astype(int)
rfmTable.rename(
    columns={
        'InvoiceDate': 'recency', 
        'InvoiceNo': 'frequency', 
        'TotalPrice': 'monetary_value'}, 
    inplace=True
)

# %%
rfmTable.head()
# Out:
#             recency  frequency  monetary_value
# CustomerID
# 12346.0         325          1        77183.60
# 12747.0           2        103         4196.01
# 12748.0           0       4596        33719.73
# 12749.0           3        199         4090.88
# 12820.0           3         59          942.34

# %%
quantiles = rfmTable.quantile(q=[0.25,0.5,0.75])
quantiles = quantiles.to_dict()

# %%
quantiles
# Out:
# {'frequency': {0.25: 17.0, 0.5: 41.0, 0.75: 99.0},
#  'monetary_value': {0.25: 300.03999999999996,
#   0.5: 651.82000000000016,
#   0.75: 1575.8900000000003},
#  'recency': {0.25: 17.0, 0.5: 50.0, 0.75: 142.0}}

# %%
def RScore(x,p,d):
    if x <= d[p][0.25]:
        return 1
    elif x <= d[p][0.50]:
        return 2
    elif x <= d[p][0.75]: 
        return 3
    else:
        return 4
    
def FMScore(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.50]:
        return 3
    elif x <= d[p][0.75]: 
        return 2
    else:
        return 1

# %%
segmented_rfm = rfmTable

segmented_rfm['r_quartile'] = segmented_rfm['recency'].apply(RScore, args=('recency',quantiles,))
segmented_rfm['f_quartile'] = segmented_rfm['frequency'].apply(FMScore, args=('frequency',quantiles,))
segmented_rfm['m_quartile'] = segmented_rfm['monetary_value'].apply(FMScore, args=('monetary_value',quantiles,))
segmented_rfm.head()
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 12346.0         325          1        77183.60           4           4
# 12747.0           2        103         4196.01           1           1
# 12748.0           0       4596        33719.73           1           1
# 12749.0           3        199         4090.88           1           1
# 12820.0           3         59          942.34           1           2
#
#             m_quartile
# CustomerID
# 12346.0              1
# 12747.0              1
# 12748.0              1
# 12749.0              1
# 12820.0              2

# %%
segmented_rfm['RFMScore'] = segmented_rfm.r_quartile.map(str) + segmented_rfm.f_quartile.map(str) + segmented_rfm.m_quartile.map(str)

segmented_rfm.head()
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 12346.0         325          1        77183.60           4           4
# 12747.0           2        103         4196.01           1           1
# 12748.0           0       4596        33719.73           1           1
# 12749.0           3        199         4090.88           1           1
# 12820.0           3         59          942.34           1           2
#
#             m_quartile RFMScore
# CustomerID
# 12346.0              1      441
# 12747.0              1      111
# 12748.0              1      111
# 12749.0              1      111
# 12820.0              2      122

# %%
segmented_rfm[segmented_rfm['RFMScore']=='111'].sort_values('monetary_value', ascending=False).head(10)
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 18102.0           0        431       259657.30           1           1
# 17450.0           8        337       194550.79           1           1
# 17511.0           2        963        91062.38           1           1
# 16684.0           4        277        66653.56           1           1
# 14096.0           4       5111        65164.79           1           1
# 13694.0           3        568        65039.62           1           1
# 15311.0           0       2379        60767.90           1           1
# 13089.0           2       1818        58825.83           1           1
# 15769.0           7        130        56252.72           1           1
# 15061.0           3        403        54534.14           1           1
#
#             m_quartile RFMScore
# CustomerID
# 18102.0              1      111
# 17450.0              1      111
# 17511.0              1      111
# 16684.0              1      111
# 14096.0              1      111
# 13694.0              1      111
# 15311.0              1      111
# 13089.0              1      111
# 15769.0              1      111
# 15061.0              1      111

# %% [markdown]
# ## Best Customers: Bought recently and most often, and spend the most

# %% [markdown]
# ### Marketing: No price incentives, new products, and loyalty programs

# %%
segmented_rfm[segmented_rfm['RFMScore']=='111'].sort_values('monetary_value', ascending=False).head(10)
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 18102.0           0        431       259657.30           1           1
# 17450.0           8        337       194550.79           1           1
# 17511.0           2        963        91062.38           1           1
# 16684.0           4        277        66653.56           1           1
# 14096.0           4       5111        65164.79           1           1
# 13694.0           3        568        65039.62           1           1
# 15311.0           0       2379        60767.90           1           1
# 13089.0           2       1818        58825.83           1           1
# 15769.0           7        130        56252.72           1           1
# 15061.0           3        403        54534.14           1           1
#
#             m_quartile RFMScore
# CustomerID
# 18102.0              1      111
# 17450.0              1      111
# 17511.0              1      111
# 16684.0              1      111
# 14096.0              1      111
# 13694.0              1      111
# 15311.0              1      111
# 13089.0              1      111
# 15769.0              1      111
# 15061.0              1      111

# %% [markdown]
# ## Loyal Customers: Buy Most Frequently

# %% [markdown]
# ### Marketing: Use R and M to Further Segment

# %%
segmented_rfm[segmented_rfm['f_quartile']==1].sort_values('monetary_value', ascending=False).head(10)
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 18102.0           0        431       259657.30           1           1
# 17450.0           8        337       194550.79           1           1
# 17511.0           2        963        91062.38           1           1
# 16029.0          38        242        81024.84           2           1
# 16684.0           4        277        66653.56           1           1
# 14096.0           4       5111        65164.79           1           1
# 13694.0           3        568        65039.62           1           1
# 15311.0           0       2379        60767.90           1           1
# 13089.0           2       1818        58825.83           1           1
# 15769.0           7        130        56252.72           1           1
#
#             m_quartile RFMScore
# CustomerID
# 18102.0              1      111
# 17450.0              1      111
# 17511.0              1      111
# 16029.0              1      211
# 16684.0              1      111
# 14096.0              1      111
# 13694.0              1      111
# 15311.0              1      111
# 13089.0              1      111
# 15769.0              1      111

# %% [markdown]
# ## Big Spenders

# %% [markdown]
# ### Marketing: Market most expensive product

# %%
segmented_rfm[segmented_rfm['m_quartile']==1].sort_values('monetary_value', ascending=False).head(10)
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 18102.0           0        431       259657.30           1           1
# 17450.0           8        337       194550.79           1           1
# 16446.0           0          3       168472.50           1           4
# 17511.0           2        963        91062.38           1           1
# 16029.0          38        242        81024.84           2           1
# 12346.0         325          1        77183.60           4           4
# 16684.0           4        277        66653.56           1           1
# 14096.0           4       5111        65164.79           1           1
# 13694.0           3        568        65039.62           1           1
# 15311.0           0       2379        60767.90           1           1
#
#             m_quartile RFMScore
# CustomerID
# 18102.0              1      111
# 17450.0              1      111
# 16446.0              1      141
# 17511.0              1      111
# 16029.0              1      211
# 12346.0              1      441
# 16684.0              1      111
# 14096.0              1      111
# 13694.0              1      111
# 15311.0              1      111

# %% [markdown]
# ## Almost Lost: havent purchased in some time, but purchased frequently and spend the most

# %% [markdown]
# ### Marketing: Aggressive price incentives

# %%
step1 = segmented_rfm[segmented_rfm['r_quartile']==3].sort_values('monetary_value', ascending=False)
step2 = step1[step1['f_quartile']==1].sort_values('monetary_value', ascending=False)
step3 = step2[step2['m_quartile']==1].sort_values('monetary_value', ascending=False)
step3
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 16180.0         100        162        10254.18           3           1
# 14952.0          59        138         8099.49           3           1
# 16745.0          86        357         7194.30           3           1
# 16652.0          58        118         6773.97           3           1
# 17509.0          57        366         6115.14           3           1
# 16984.0          88        407         4481.35           3           1
# 15874.0          63        120         4405.88           3           1
# 13555.0          73        136         4149.28           3           1
# 15416.0          64        192         3984.32           3           1
# 13124.0          89        235         3866.33           3           1
# 13552.0          66        109         3740.07           3           1
# 16253.0          66        123         3683.86           3           1
# 15581.0         120        150         3679.97           3           1
# 13334.0          82        268         3536.82           3           1
# 15410.0          84        122         3450.84           3           1
# 15228.0          66        125         3386.71           3           1
# 13842.0          58        206         3385.62           3           1
# 13015.0          53        176         3346.28           3           1
# 16556.0          66        207         3313.79           3           1
# 13373.0          60        158         3312.25           3           1
# 14841.0          53        138         3295.76           3           1
# 15764.0          88        180         3279.97           3           1
# 17050.0          96        316         3228.84           3           1
# 14175.0          59        149         3222.30           3           1
# 14844.0          63        130         3189.81           3           1
# 17863.0          59        148         3160.00           3           1
# 13869.0         123        307         3104.95           3           1
# 15491.0          95        154         3100.09           3           1
# 14257.0          64        106         3099.72           3           1
# 14565.0          95        127         3099.12           3           1
# ...             ...        ...             ...         ...         ...
# 15834.0          70        273         2233.75           3           1
# 17591.0          73        166         2225.97           3           1
# 16456.0          99        111         2158.37           3           1
# 13224.0          60        108         2155.95           3           1
# 17400.0         126        213         2129.96           3           1
# 13517.0          59        141         2128.42           3           1
# 16875.0          67        112         2095.53           3           1
# 17667.0          66        117         2055.51           3           1
# 17612.0          53        135         2048.45           3           1
# 13593.0         108        128         2037.08           3           1
# 14462.0          66        240         2004.02           3           1
# 18204.0          71        200         1993.70           3           1
# 17997.0          74        166         1970.67           3           1
# 15518.0          64        214         1942.45           3           1
# 14472.0         103        281         1936.84           3           1
# 14978.0          72        216         1931.42           3           1
# 14210.0         105        102         1905.84           3           1
# 15641.0         105        119         1887.20           3           1
# 14305.0          71        105         1858.96           3           1
# 15827.0          73        115         1836.09           3           1
# 18235.0          71        104         1796.48           3           1
# 13875.0          53        104         1786.79           3           1
# 15220.0          51        117         1778.96           3           1
# 15241.0          66        110         1756.44           3           1
# 12843.0          65        103         1702.26           3           1
# 15549.0          77        115         1693.26           3           1
# 17284.0          60        292         1652.58           3           1
# 14837.0          89        108         1649.50           3           1
# 15002.0         115        115         1641.76           3           1
# 16515.0          52        113         1627.13           3           1
#
#             m_quartile RFMScore
# CustomerID
# 16180.0              1      311
# 14952.0              1      311
# 16745.0              1      311
# 16652.0              1      311
# 17509.0              1      311
# 16984.0              1      311
# 15874.0              1      311
# 13555.0              1      311
# 15416.0              1      311
# 13124.0              1      311
# 13552.0              1      311
# 16253.0              1      311
# 15581.0              1      311
# 13334.0              1      311
# 15410.0              1      311
# 15228.0              1      311
# 13842.0              1      311
# 13015.0              1      311
# 16556.0              1      311
# 13373.0              1      311
# 14841.0              1      311
# 15764.0              1      311
# 17050.0              1      311
# 14175.0              1      311
# 14844.0              1      311
# 17863.0              1      311
# 13869.0              1      311
# 15491.0              1      311
# 14257.0              1      311
# 14565.0              1      311
# ...                ...      ...
# 15834.0              1      311
# 17591.0              1      311
# 16456.0              1      311
# 13224.0              1      311
# 17400.0              1      311
# 13517.0              1      311
# 16875.0              1      311
# 17667.0              1      311
# 17612.0              1      311
# 13593.0              1      311
# 14462.0              1      311
# 18204.0              1      311
# 17997.0              1      311
# 15518.0              1      311
# 14472.0              1      311
# 14978.0              1      311
# 14210.0              1      311
# 15641.0              1      311
# 14305.0              1      311
# 15827.0              1      311
# 18235.0              1      311
# 13875.0              1      311
# 15220.0              1      311
# 15241.0              1      311
# 12843.0              1      311
# 15549.0              1      311
# 17284.0              1      311
# 14837.0              1      311
# 15002.0              1      311
# 16515.0              1      311
#
# [92 rows x 7 columns]

# %% [markdown]
# ## Lost Customers: Haven't purhased for some time, but purchased frequently and spend the most

# %% [markdown]
# ### Marketing: Aggressive price incentives

# %%
step1 = segmented_rfm[segmented_rfm['r_quartile']==4].sort_values('monetary_value', ascending=False)
step2 = step1[step1['f_quartile']==1].sort_values('monetary_value', ascending=False)
step3 = step2[step2['m_quartile']==1].sort_values('monetary_value', ascending=False)
step3
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 13093.0         275        159        7832.470           4           1
# 17850.0         372        297        5391.210           4           1
# 15808.0         306        208        3734.970           4           1
# 15379.0         169        194        3703.290           4           1
# 13952.0         217        137        3251.071           4           1
# 17504.0         206        127        2997.030           4           1
# 12840.0         143        113        2726.770           4           1
# 18260.0         172        134        2643.200           4           1
# 16919.0         156        327        2596.450           4           1
# 15235.0         217        143        2247.510           4           1
# 15665.0         168        116        2242.010           4           1
# 17406.0         333        113        2200.420           4           1
# 14461.0         148        180        2103.060           4           1
# 18231.0         192        124        2083.270           4           1
# 17337.0         151        543        2027.870           4           1
# 17787.0         152        134        1865.190           4           1
# 14245.0         219        108        1693.450           4           1
# 14573.0         179        235        1653.420           4           1
# 12868.0         185        107        1607.060           4           1
# 16889.0         194        135        1578.670           4           1
#
#             m_quartile RFMScore
# CustomerID
# 13093.0              1      411
# 17850.0              1      411
# 15808.0              1      411
# 15379.0              1      411
# 13952.0              1      411
# 17504.0              1      411
# 12840.0              1      411
# 18260.0              1      411
# 16919.0              1      411
# 15235.0              1      411
# 15665.0              1      411
# 17406.0              1      411
# 14461.0              1      411
# 18231.0              1      411
# 17337.0              1      411
# 17787.0              1      411
# 14245.0              1      411
# 14573.0              1      411
# 12868.0              1      411
# 16889.0              1      411

# %% [markdown]
# ## Lost Cheap Customers: Last purchased long ago, purchased few, and spent little

# %% [markdown]
# ### Marketing: Don't spend too much to reacquire

# %%
step1 = segmented_rfm[segmented_rfm['r_quartile']==4].sort_values('monetary_value', ascending=False)
step2 = step1[step1['f_quartile']==4].sort_values('monetary_value', ascending=False)
step3 = step2[step2['m_quartile']==4].sort_values('monetary_value', ascending=False)
step3
# Out:
#             recency  frequency  monetary_value  r_quartile  f_quartile  \
# CustomerID
# 15609.0         184         16          298.48           4           4
# 17678.0         263         16          298.11           4           4
# 12881.0         275          7          298.00           4           4
# 17531.0         190         14          296.70           4           4
# 13751.0         288          9          296.25           4           4
# 16998.0         149          4          295.00           4           4
# 15732.0         212         14          294.12           4           4
# 12829.0         336         11          293.00           4           4
# 16526.0         171         15          290.36           4           4
# 17464.0         158          9          289.96           4           4
# 16125.0         367         13          289.35           4           4
# 18190.0         192         15          284.46           4           4
# 13754.0         151         12          282.60           4           4
# 14242.0         234         16          280.55           4           4
# 13803.0         255         17          277.07           4           4
# 14816.0         197          4          271.85           4           4
# 17496.0         358         10          271.05           4           4
# 18108.0         254         17          271.00           4           4
# 14727.0         274         10          268.58           4           4
# 15119.0         245         14          266.40           4           4
# 14423.0         218          3          265.20           4           4
# 13973.0         287         11          264.70           4           4
# 15143.0         225         14          259.45           4           4
# 13227.0         201          9          257.70           4           4
# 16048.0         373          8          256.44           4           4
# 16226.0         203          8          255.12           4           4
# 15759.0         218          7          253.04           4           4
# 15346.0         332         17          252.42           4           4
# 13711.0         218         13          252.06           4           4
# 16976.0         267          2          251.52           4           4
# ...             ...        ...             ...         ...         ...
# 14840.0         267          4           62.85           4           4
# 17174.0         217          4           59.90           4           4
# 13391.0         203          1           59.80           4           4
# 13682.0         187          3           59.50           4           4
# 14957.0         253         12           58.49           4           4
# 13080.0         179          6           58.08           4           4
# 17775.0         254          3           56.40           4           4
# 15899.0         368          4           56.25           4           4
# 16349.0         290          9           53.50           4           4
# 14682.0         187          2           52.00           4           4
# 14351.0         164          1           51.00           4           4
# 13011.0         372          3           50.55           4           4
# 14821.0         366          2           48.80           4           4
# 16257.0         176          2           46.95           4           4
# 15178.0         260          3           40.50           4           4
# 14589.0         371          3           39.75           4           4
# 12977.0         156          9           39.24           4           4
# 16659.0         189          2           39.12           4           4
# 12855.0         372          3           38.10           4           4
# 16162.0         252          2           37.40           4           4
# 15940.0         311          1           35.80           4           4
# 14576.0         372          1           35.40           4           4
# 16765.0         294          1           34.00           4           4
# 17408.0         163          2           32.65           4           4
# 13120.0         238          1           30.60           4           4
# 17102.0         261          1           25.50           4           4
# 15823.0         372          1           15.00           4           4
# 17763.0         263          1           15.00           4           4
# 17956.0         249          1           12.75           4           4
# 16738.0         297          1            3.75           4           4
#
#             m_quartile RFMScore
# CustomerID
# 15609.0              4      444
# 17678.0              4      444
# 12881.0              4      444
# 17531.0              4      444
# 13751.0              4      444
# 16998.0              4      444
# 15732.0              4      444
# 12829.0              4      444
# 16526.0              4      444
# 17464.0              4      444
# 16125.0              4      444
# 18190.0              4      444
# 13754.0              4      444
# 14242.0              4      444
# 13803.0              4      444
# 14816.0              4      444
# 17496.0              4      444
# 18108.0              4      444
# 14727.0              4      444
# 15119.0              4      444
# 14423.0              4      444
# 13973.0              4      444
# 15143.0              4      444
# 13227.0              4      444
# 16048.0              4      444
# 16226.0              4      444
# 15759.0              4      444
# 15346.0              4      444
# 13711.0              4      444
# 16976.0              4      444
# ...                ...      ...
# 14840.0              4      444
# 17174.0              4      444
# 13391.0              4      444
# 13682.0              4      444
# 14957.0              4      444
# 13080.0              4      444
# 17775.0              4      444
# 15899.0              4      444
# 16349.0              4      444
# 14682.0              4      444
# 14351.0              4      444
# 13011.0              4      444
# 14821.0              4      444
# 16257.0              4      444
# 15178.0              4      444
# 14589.0              4      444
# 12977.0              4      444
# 16659.0              4      444
# 12855.0              4      444
# 16162.0              4      444
# 15940.0              4      444
# 14576.0              4      444
# 16765.0              4      444
# 17408.0              4      444
# 13120.0              4      444
# 17102.0              4      444
# 15823.0              4      444
# 17763.0              4      444
# 17956.0              4      444
# 16738.0              4      444
#
# [343 rows x 7 columns]
